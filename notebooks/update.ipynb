# %%
# %%writefile ../update.py
#!/usr/bin/env python

# DO NOT EDIT THIS FILE : Generated from scribe/notebooks/wakeword.ipynb

from  mangorest.mango import webapi
import colabexts.utils as colabexts_utils
import logging, os, datetime
logger = logging.getLogger( "geoapp" )

# ------------------------------------------------------------------------------
@webapi("/asthma/update/")
def updateRecord(request=None, **kwargs): 
    user_id = kwargs.get('user_id', '')
    cur_time = kwargs.get('cur_time', '')  
    logger.info( f"+++++++++++ {user_id} {cur_time}" )
    if not user_id:
        return "no userid!!"
    
    return f"updated !!"

if __name__ == '__main__' and not colabexts_utils.inJupyter():
    updateRecord(None, None)
# Out:
# Overwriting ../update.py

# %%
import datetime


u, d = "sada 9/30/2025 21:04:27".split()
print(u, d)
dd= datetime.datetime.fromisoformat(d)
print(dd)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 4
#       1 import datetime
# ----> 4 u, d = "sada 9/30/2025 21:04:27".split()
#       5 print(u, d)
#       6 dd= datetime.datetime.fromisoformat(d)
#
# ValueError: too many values to unpack (expected 2)

# %%
from dateutil import parser
dt =parser.parse('9/30/2025, 11:04:27 PM')
#write code to detect ampm
ampm = ( dt.strftime('%p') == 'PM')
print(dt)
# Out:
# 2025-09-30 23:04:27
